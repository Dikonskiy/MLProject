# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ap_data.csv')
df.head()
# Out:
#         price  room_count  quadrature floor_text  floor        region_text  \
# 0    31000000           2        60.0       8/12   0.67     Алатауский р-н
# 1    25000000           2        47.0        3/9   0.33     Алатауский р-н
# 2  1861400000           6       521.1      20/22   0.91  Бостандыкский р-н
# 3  1861400000           6       521.0      20/22   0.91  Бостандыкский р-н
# 4  1861400000           5       521.0      20/22   0.91             Алматы
#
#          region  year    flat_toilet                   flat_balcony  \
# 0  1.000000e-10  2019    совмещенный                        no_info
# 1  1.000000e-10  2011    совмещенный                        no_info
# 2  1.000000e+00  2015  2 с/у и более                         лоджия
# 3  1.000000e+00  2015        no_info                        no_info
# 4           NaN  2015  2 с/у и более  несколько балконов или лоджий
#
#   flat_balcony_g      flat_door  inet_type              flat_parking  \
# 0        no_info  металлическая       ADSL  рядом охраняемая стоянка
# 1        no_info  металлическая  проводной                   no_info
# 2             да  металлическая    no_info                   паркинг
# 3        no_info        no_info    no_info                   no_info
# 4        no_info  металлическая    no_info                   no_info
#
#   live_furniture flat_flooring  ceiling
# 0       частично       ламинат      2.7
# 1     без мебели       ламинат      2.7
# 2       частично        паркет      2.8
# 3        no_info       no_info      2.8
# 4        no_info        паркет      2.8

# %%
df.isna().sum()
# Out:
# price                 0
# room_count            0
# quadrature            0
# floor_text            0
# floor                 0
# region_text           0
# region             1051
# year                  0
# flat_toilet        1819
# flat_balcony       1819
# flat_balcony_g     1819
# flat_door          1819
# inet_type          1819
# flat_parking       1819
# live_furniture     1819
# flat_flooring      1819
# ceiling           11580
# dtype: int64

# %%
region_mean = df['region'].mean()
df['region'].fillna(region_mean, inplace=True)

# %%
ceiling_mean = round(df['ceiling'].mean(), 2)
df['ceiling'].fillna(ceiling_mean, inplace=True)

# %%
print(df.shape)
df.isna().sum()
# Out:
# (36111, 17)
# price                0
# room_count           0
# quadrature           0
# floor_text           0
# floor                0
# region_text          0
# region               0
# year                 0
# flat_toilet       1819
# flat_balcony      1819
# flat_balcony_g    1819
# flat_door         1819
# inet_type         1819
# flat_parking      1819
# live_furniture    1819
# flat_flooring     1819
# ceiling              0
# dtype: int64

# %%
df.dropna(inplace=True)
print(df.shape)
df.isna().sum()
# Out:
# (34292, 17)
# price             0
# room_count        0
# quadrature        0
# floor_text        0
# floor             0
# region_text       0
# region            0
# year              0
# flat_toilet       0
# flat_balcony      0
# flat_balcony_g    0
# flat_door         0
# inet_type         0
# flat_parking      0
# live_furniture    0
# flat_flooring     0
# ceiling           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['price', 'room_count', 'quadrature', 'floor_text', 'floor',
#        'region_text', 'region', 'year', 'flat_toilet', 'flat_balcony',
#        'flat_balcony_g', 'flat_door', 'inet_type', 'flat_parking',
#        'live_furniture', 'flat_flooring', 'ceiling'],
#       dtype='object')

# %%
columns_to_encode = ['flat_toilet', 'flat_balcony', 'flat_balcony_g', 'flat_door', 'inet_type', 'flat_parking', 'live_furniture', 'flat_flooring']
df = pd.get_dummies(df, columns=columns_to_encode, drop_first=True)
df
# Out:
#             price  room_count  quadrature floor_text  floor  \
# 0        31000000           2        60.0       8/12   0.67
# 1        25000000           2        47.0        3/9   0.33
# 2      1861400000           6       521.1      20/22   0.91
# 3      1861400000           6       521.0      20/22   0.91
# 4      1861400000           5       521.0      20/22   0.91
# ...           ...         ...         ...        ...    ...
# 36105    39500000           3        59.0        3/5   0.60
# 36107    39500000           3        59.0        2/5   0.40
# 36108    39500000           3        66.0        4/5   0.80
# 36109    39500000           2        50.2        2/5   0.40
# 36110    39500000           2        47.0        1/5   0.20
#
#              region_text        region  year  ceiling  flat_toilet_no_info  \
# 0         Алатауский р-н  1.000000e-10  2019     2.70                False
# 1         Алатауский р-н  1.000000e-10  2011     2.70                False
# 2      Бостандыкский р-н  1.000000e+00  2015     2.80                False
# 3      Бостандыкский р-н  1.000000e+00  2015     2.80                 True
# 4                 Алматы  4.855513e-01  2015     2.80                False
# ...                  ...           ...   ...      ...                  ...
# 36105  Бостандыкский р-н  1.000000e+00  1975     2.87                 True
# 36107  Бостандыкский р-н  1.000000e+00  1983     2.87                 True
# 36108    Алмалинский р-н  7.500000e-02  1980     2.75                 True
# 36109    Алмалинский р-н  7.500000e-02  1977     2.87                 True
# 36110    Алмалинский р-н  7.500000e-02  1987     2.87                 True
#
#        ...  live_furniture_без мебели  live_furniture_полностью  \
# 0      ...                      False                     False
# 1      ...                       True                     False
# 2      ...                      False                     False
# 3      ...                      False                     False
# 4      ...                      False                     False
# ...    ...                        ...                       ...
# 36105  ...                      False                     False
# 36107  ...                      False                     False
# 36108  ...                      False                     False
# 36109  ...                      False                     False
# 36110  ...                      False                     False
#
#        live_furniture_частично  flat_flooring_дерево  flat_flooring_ковролан  \
# 0                         True                 False                   False
# 1                        False                 False                   False
# 2                         True                 False                   False
# 3                        False                 False                   False
# 4                        False                 False                   False
# ...                        ...                   ...                     ...
# 36105                    False                 False                   False
# 36107                    False                 False                   False
# 36108                     True                 False                   False
# 36109                     True                 False                   False
# 36110                    False                 False                   False
#
#        flat_flooring_ламинат  flat_flooring_линолеум  flat_flooring_паркет  \
# 0                       True                   False                 False
# 1                       True                   False                 False
# 2                      False                   False                  True
# 3                      False                   False                 False
# 4                      False                   False                  True
# ...                      ...                     ...                   ...
# 36105                  False                   False                 False
# 36107                  False                   False                 False
# 36108                   True                   False                 False
# 36109                  False                   False                  True
# 36110                  False                   False                 False
#
#        flat_flooring_плитка  flat_flooring_пробковый
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
# ...                     ...                      ...
# 36105                 False                    False
# 36107                 False                    False
# 36108                 False                    False
# 36109                 False                    False
# 36110                 False                    False
#
# [34292 rows x 39 columns]

# %%
df = df.select_dtypes(exclude='object')
df
# Out:
#             price  room_count  quadrature  floor        region  year  ceiling  \
# 0        31000000           2        60.0   0.67  1.000000e-10  2019     2.70
# 1        25000000           2        47.0   0.33  1.000000e-10  2011     2.70
# 2      1861400000           6       521.1   0.91  1.000000e+00  2015     2.80
# 3      1861400000           6       521.0   0.91  1.000000e+00  2015     2.80
# 4      1861400000           5       521.0   0.91  4.855513e-01  2015     2.80
# ...           ...         ...         ...    ...           ...   ...      ...
# 36105    39500000           3        59.0   0.60  1.000000e+00  1975     2.87
# 36107    39500000           3        59.0   0.40  1.000000e+00  1983     2.87
# 36108    39500000           3        66.0   0.80  7.500000e-02  1980     2.75
# 36109    39500000           2        50.2   0.40  7.500000e-02  1977     2.87
# 36110    39500000           2        47.0   0.20  7.500000e-02  1987     2.87
#
#        flat_toilet_no_info  flat_toilet_нет  flat_toilet_раздельный  ...  \
# 0                    False            False                   False  ...
# 1                    False            False                   False  ...
# 2                    False            False                   False  ...
# 3                     True            False                   False  ...
# 4                    False            False                   False  ...
# ...                    ...              ...                     ...  ...
# 36105                 True            False                   False  ...
# 36107                 True            False                   False  ...
# 36108                 True            False                   False  ...
# 36109                 True            False                   False  ...
# 36110                 True            False                   False  ...
#
#        live_furniture_без мебели  live_furniture_полностью  \
# 0                          False                     False
# 1                           True                     False
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
# ...                          ...                       ...
# 36105                      False                     False
# 36107                      False                     False
# 36108                      False                     False
# 36109                      False                     False
# 36110                      False                     False
#
#        live_furniture_частично  flat_flooring_дерево  flat_flooring_ковролан  \
# 0                         True                 False                   False
# 1                        False                 False                   False
# 2                         True                 False                   False
# 3                        False                 False                   False
# 4                        False                 False                   False
# ...                        ...                   ...                     ...
# 36105                    False                 False                   False
# 36107                    False                 False                   False
# 36108                     True                 False                   False
# 36109                     True                 False                   False
# 36110                    False                 False                   False
#
#        flat_flooring_ламинат  flat_flooring_линолеум  flat_flooring_паркет  \
# 0                       True                   False                 False
# 1                       True                   False                 False
# 2                      False                   False                  True
# 3                      False                   False                 False
# 4                      False                   False                  True
# ...                      ...                     ...                   ...
# 36105                  False                   False                 False
# 36107                  False                   False                 False
# 36108                   True                   False                 False
# 36109                  False                   False                  True
# 36110                  False                   False                 False
#
#        flat_flooring_плитка  flat_flooring_пробковый
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
# ...                     ...                      ...
# 36105                 False                    False
# 36107                 False                    False
# 36108                 False                    False
# 36109                 False                    False
# 36110                 False                    False
#
# [34292 rows x 37 columns]

# %%
# df['log_quadrature'] = np.log1p(df['quadrature'])
# df['log_region'] = np.log1p(df['region'])
# df['log_ceiling'] = np.log1p(df['ceiling'])
# df

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_columns = df.columns

for x_column in numerical_columns:
    if x_column != 'price':
        plt.figure(figsize=(4, 3))
        plt.scatter(df[x_column], df['price'])
        plt.xlabel(x_column)
        plt.ylabel('Y')
        plt.title(f'Scatter Plot of {x_column} vs. Price')
        plt.show()

# %%
numerical_columns = ['price', 'room_count', 'quadrature', 'floor', 'region', 'year', 'ceiling']
# For each column, drop the outliers
for column in numerical_columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Filter the dataframe
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Once outliers are removed, visualize your data
for x_column in numerical_columns:
    if x_column != 'price':
        plt.figure(figsize=(4, 3))
        plt.scatter(df[x_column], df['price'])
        plt.xlabel(x_column)
        plt.ylabel('Y')
        plt.title(f'Scatter Plot of {x_column} vs. Price')
        plt.show()

# %%
# Assuming you have a DataFrame called 'df'
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(20, 15))  # Adjust the figure size if needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# Set plot title
plt.title("Correlation Matrix Heatmap")

# Show the heatmap
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
features_to_normalize = ['room_count', 'quadrature', 'year', 'ceiling']
df[features_to_normalize] = scaler.fit_transform(df[features_to_normalize])

# %%
from sklearn.preprocessing import MinMaxScaler
import random

def get_user_input():
    # Get input from user
    user_data = {}
    user_data['room_count'] = float(input("Enter room count: "))
    user_data['quadrature'] = float(input("Enter quadrature: "))
    user_data['floor'] = float(input("Enter floor coeffcoefficient: "))
    user_data['region'] = float(input("Enter region coefficient: "))
    user_data['year'] = float(input("Enter year: "))
    user_data['ceiling'] = float(input("Enter ceiling height (e.g., 2.7 for 2.7m): "))

    options_mapping = {
        'flat_toilet': ['no_info', 'нет', 'раздельный', 'совмещенный'],
        'flat_balcony': ['балкон', 'балкон и лоджия', 'лоджия', 'несколько балконов или лоджий'],
        'flat_balcony_g': ['да', 'нет'],
        'flat_door': ['бронированная', 'деревянная', 'металлическая'],
        'inet_type': ['no_info', 'оптика', 'проводной', 'через TV кабель'],
        'flat_parking': ['гараж', 'паркинг', 'рядом охраняемая стоянка'],
        'live_furniture': ['без мебели', 'полностью', 'частично'],
        'flat_flooring': ['дерево', 'ковролан', 'ламинат', 'линолеум', 'паркет', 'плитка', 'пробковый']
    }

    for prefix, options in options_mapping.items():
        chosen_option = random.choice(options)
        values = [1 if opt == chosen_option else 0 for opt in options]
        cols = [str(prefix)+'_'+ str(opt) for opt in options]
        # col = "'" + "', '".join(map(str, cols))+"'"
        for i in range(len(values)):
            user_data[cols[i]] = values[i]  # Fill missing columns with default or most common value
            
    # Create a DataFrame with the correct data types
    user_input_df = pd.DataFrame(np.zeros((1, len(X_train.columns))), columns=X_train.columns)
    user_input_df = user_input_df.astype(float)  # Ensure all columns are float64 type
    
    # Update the DataFrame with the user's input
    for feature in user_data:
        user_input_df.at[0, feature] = user_data[feature]
    
    # Normalize and standardize the user's input
    user_input_df[features_to_normalize] = scaler.transform(user_input_df[features_to_normalize])
    user_input_df = stdScaler.transform(user_input_df)
    
    return user_input_df
    
def predict_price(user_input_df):
    
    # options_mapping = {
    #     'flat_toilet': ['no_info', 'нет', 'раздельный', 'совмещенный'],
    #     'flat_balcony': ['балкон', 'балкон и лоджия', 'лоджия', 'несколько балконов или лоджий'],
    #     'flat_balcony_g': ['да', 'нет'],
    #     'flat_door': ['бронированная', 'деревянная', 'металлическая'],
    #     'inet_type': ['no_info', 'оптика', 'проводной', 'через TV кабель'],
    #     'flat_parking': ['гараж', 'паркинг', 'рядом охраняемая стоянка'],
    #     'live_furniture': ['без мебели', 'полностью', 'частично'],
    #     'flat_flooring': ['дерево', 'ковролан', 'ламинат', 'линолеум', 'паркет', 'плитка', 'пробковый']
    # }
    
    # Normalize user input
    # features_to_normalize = ['room_count', 'quadrature', 'year', 'ceiling']
    # user_input_df[features_to_normalize] = scaler.transform(user_input_df[features_to_normalize])
        
    # for prefix, options in options_mapping.items():
    #     chosen_option = random.choice(options)
    #     values = [1 if opt == chosen_option else 0 for opt in options]
    #     cols = [str(prefix)+'_'+ str(opt) for opt in options]
    #     # col = "'" + "', '".join(map(str, cols))+"'"
    #     for i in range(len(values)):
    #         user_input_df[cols[i]] = values[i]  # Fill missing columns with default or most common value
        
    # Predict price
    price_pred = model.predict(user_input_df)
    return price_pred[0]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

stdScaler = StandardScaler()

# Split the data into training and testing sets
X = df.drop('price', axis=1)
print(X.columns)
y = df['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

X_train_scaled = stdScaler.fit_transform(X_train)
X_test_scaled = stdScaler.transform(X_test)

# Define the models
models = {
    # "Linear Regression": LinearRegression(),
    # "Ridge": Ridge(),
    # "Lasso": Lasso(),
    "Random Forest": RandomForestRegressor(random_state=42),
    # "Gradient Boosting": GradientBoostingRegressor(random_state=42),
    # "Extra Trees": ExtraTreesRegressor(random_state=42),
    # "KNN": KNeighborsRegressor(n_neighbors=13),
    # "Support Vector Regression": SVR(),
    # "Decision Tree": DecisionTreeRegressor(random_state=42),
    # "Neural Network": MLPRegressor(batch_size=32, learning_rate_init=0.01, max_iter=10000, random_state=42)
}

# Train and evaluate each model

user_input_df = get_user_input()
# print(user_input_df.columns)

for name, model in models.items():
    # Train the model
    model.fit(X_train_scaled, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test_scaled)
    
    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f"{name}: Mean Squared Error: {mse}")
    print(f"{name}: R² Score: {r2}")
    print()
    
    predicted_price = predict_price(user_input_df)
    print(f"Predicted Apartment Price: {predicted_price}")
# Out:
# Index(['room_count', 'quadrature', 'floor', 'region', 'year', 'ceiling',
#        'flat_toilet_no_info', 'flat_toilet_нет', 'flat_toilet_раздельный',
#        'flat_toilet_совмещенный', 'flat_balcony_балкон',
#        'flat_balcony_балкон и лоджия', 'flat_balcony_лоджия',
#        'flat_balcony_несколько балконов или лоджий', 'flat_balcony_g_да',
#        'flat_balcony_g_нет', 'flat_door_бронированная', 'flat_door_деревянная',
#        'flat_door_металлическая', 'inet_type_no_info', 'inet_type_оптика',
#        'inet_type_проводной', 'inet_type_через TV кабель',
#        'flat_parking_гараж', 'flat_parking_паркинг',
#        'flat_parking_рядом охраняемая стоянка', 'live_furniture_без мебели',
#        'live_furniture_полностью', 'live_furniture_частично',
#        'flat_flooring_дерево', 'flat_flooring_ковролан',
#        'flat_flooring_ламинат', 'flat_flooring_линолеум',
#        'flat_flooring_паркет', 'flat_flooring_плитка',
#        'flat_flooring_пробковый'],
#       dtype='object')
# Enter room count:  5
# Enter quadrature:  400
# Enter floor coeffcoefficient:  0.89
# Enter region coefficient:  0.69
# Enter year:  2014
# Enter ceiling height (e.g., 2.7 for 2.7m):  3.0
# Random Forest: Mean Squared Error: 45902347753941.625
# Random Forest: R² Score: 0.8555304381443601
#
# Predicted Apartment Price: 77867019.4
